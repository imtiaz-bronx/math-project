# %% [markdown]
# # Imtiaz Mahmud

# %% [markdown]
# # MileStone1 - NYC Yellow Taxi - March 1 - 3, 2023.</div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf

import graphviz

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz

from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
x = pd.read_csv("https://raw.githubusercontent.com/imtiaz-bronx/math-project/refs/heads/main/Files/YTM123.csv")
x
# Out:
# /tmp/ipykernel_6799/3566360131.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   x = pd.read_csv("https://raw.githubusercontent.com/imtiaz-bronx/math-project/refs/heads/main/Files/YTM123.csv")
#         VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0              2  03/01/2023 12:00:00 AM  03/01/2023 12:28:03 AM
# 1              2  03/01/2023 12:00:00 AM  03/01/2023 12:00:00 AM
# 2              2  03/01/2023 12:00:00 AM  03/01/2023 12:15:00 AM
# 3              2  03/01/2023 12:00:01 AM  03/01/2023 12:25:17 AM
# 4              2  03/01/2023 12:00:05 AM  03/01/2023 12:14:11 AM
# ...          ...                     ...                     ...
# 234239         1  03/02/2023 11:59:59 PM  03/03/2023 12:08:10 AM
# 234240         2  03/02/2023 11:59:59 PM  03/03/2023 12:27:50 AM
# 234241         1  03/03/2023 12:00:00 AM  03/03/2023 12:24:02 AM
# 234242         2  03/03/2023 12:00:00 AM  03/03/2023 12:04:39 AM
# 234243         2  03/03/2023 12:00:00 AM  03/03/2023 12:22:00 AM
#
#         passenger_count trip_distance  RatecodeID store_and_fwd_flag  \
# 0                   1.0         12.77         1.0                  N
# 1                   3.0          6.22         1.0                  N
# 2                   NaN          3.83         NaN                NaN
# 3                   1.0         13.93         1.0                  N
# 4                   2.0           2.9         1.0                  N
# ...                 ...           ...         ...                ...
# 234239              1.0           1.0         1.0                  N
# 234240              NaN         12.49         NaN                NaN
# 234241              1.0           8.4         1.0                  N
# 234242              2.0          0.56         1.0                  N
# 234243              NaN          5.71         NaN                NaN
#
#         PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0                138            87             1        51.30   6.00      0.5
# 1                162            13             2        29.60   0.00      0.5
# 2                 68           238             0        18.14   0.00      0.5
# 3                132           155             1        54.10   1.00      0.5
# 4                234            13             1        16.30   1.00      0.5
# ...              ...           ...           ...          ...    ...      ...
# 234239            79           113             1         7.90   3.50      0.5
# 234240            88           223             0        44.87   0.00      0.5
# 234241           138            24             1        35.90   7.25      0.5
# 234242           114           158             1         5.80   1.00      0.5
# 234243            79           238             0        24.47   0.00      0.5
#
#         tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0             5.00          6.55                    1.0         74.10
# 1             0.00          0.00                    1.0         33.60
# 2             4.43          0.00                    1.0         26.57
# 3            11.32          0.00                    1.0         69.17
# 4             3.00          0.00                    1.0         24.30
# ...            ...           ...                    ...           ...
# 234239        1.00          0.00                    1.0         13.90
# 234240        4.89          0.00                    1.0         53.76
# 234241        5.00          6.55                    1.0         56.20
# 234242        2.16          0.00                    1.0         12.96
# 234243        5.69          0.00                    1.0         34.16
#
#         congestion_surcharge  airport_fee
# 0                        2.5         1.25
# 1                        2.5         0.00
# 2                        NaN          NaN
# 3                        0.0         1.25
# 4                        2.5         0.00
# ...                      ...          ...
# 234239                   2.5         0.00
# 234240                   NaN          NaN
# 234241                   0.0         1.25
# 234242                   2.5         0.00
# 234243                   NaN          NaN
#
# [234244 rows x 19 columns]

# %% [markdown]
# ### About the Date:

# %%
x.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance             object
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# airport_fee              float64
# dtype: object

# %%
x.tail(5)
# Out:
#         VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 234239         1  03/02/2023 11:59:59 PM  03/03/2023 12:08:10 AM
# 234240         2  03/02/2023 11:59:59 PM  03/03/2023 12:27:50 AM
# 234241         1  03/03/2023 12:00:00 AM  03/03/2023 12:24:02 AM
# 234242         2  03/03/2023 12:00:00 AM  03/03/2023 12:04:39 AM
# 234243         2  03/03/2023 12:00:00 AM  03/03/2023 12:22:00 AM
#
#         passenger_count trip_distance  RatecodeID store_and_fwd_flag  \
# 234239              1.0           1.0         1.0                  N
# 234240              NaN         12.49         NaN                NaN
# 234241              1.0           8.4         1.0                  N
# 234242              2.0          0.56         1.0                  N
# 234243              NaN          5.71         NaN                NaN
#
#         PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 234239            79           113             1         7.90   3.50      0.5
# 234240            88           223             0        44.87   0.00      0.5
# 234241           138            24             1        35.90   7.25      0.5
# 234242           114           158             1         5.80   1.00      0.5
# 234243            79           238             0        24.47   0.00      0.5
#
#         tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 234239        1.00          0.00                    1.0         13.90
# 234240        4.89          0.00                    1.0         53.76
# 234241        5.00          6.55                    1.0         56.20
# 234242        2.16          0.00                    1.0         12.96
# 234243        5.69          0.00                    1.0         34.16
#
#         congestion_surcharge  airport_fee
# 234239                   2.5         0.00
# 234240                   NaN          NaN
# 234241                   0.0         1.25
# 234242                   2.5         0.00
# 234243                   NaN          NaN

# %%
x['tpep_pickup_datetime'] = pd.to_datetime(x['tpep_pickup_datetime'])
x['tpep_dropoff_datetime'] = pd.to_datetime(x['tpep_dropoff_datetime'])
x.dtypes
# Out:
# /tmp/ipykernel_6799/4005381308.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x['tpep_pickup_datetime'] = pd.to_datetime(x['tpep_pickup_datetime'])
# /tmp/ipykernel_6799/4005381308.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x['tpep_dropoff_datetime'] = pd.to_datetime(x['tpep_dropoff_datetime'])
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                    object
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
dup_filter = x.duplicated()
x[dup_filter]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
x.describe()
# Out:
#             VendorID           tpep_pickup_datetime  \
# count  234244.000000                         234244
# mean        1.721282  2023-03-02 03:25:51.752873472
# min         1.000000            2023-03-01 00:00:00
# 25%         1.000000            2023-03-01 15:50:12
# 50%         2.000000            2023-03-02 00:51:50
# 75%         2.000000            2023-03-02 16:03:22
# max         6.000000            2023-03-03 00:00:00
# std         0.461507                            NaN
#
#                tpep_dropoff_datetime  passenger_count     RatecodeID  \
# count                         234244    228205.000000  228205.000000
# mean   2023-03-02 03:42:37.366225152         1.295287       1.662667
# min              2023-03-01 00:00:00         0.000000       1.000000
# 25%              2023-03-01 16:08:30         1.000000       1.000000
# 50%       2023-03-02 01:08:28.500000         1.000000       1.000000
# 75%    2023-03-02 16:22:09.249999872         1.000000       1.000000
# max              2023-03-03 23:19:44         6.000000      99.000000
# std                              NaN         0.849248       7.671498
#
#         PULocationID   DOLocationID   payment_type    fare_amount  \
# count  234244.000000  234244.000000  234244.000000  234244.000000
# mean      167.495748     165.808588       1.172786      18.538090
# min         1.000000       1.000000       0.000000    -229.800000
# 25%       132.000000     125.000000       1.000000       9.300000
# 50%       162.000000     162.000000       1.000000      13.500000
# 75%       234.000000     234.000000       1.000000      20.500000
# max       265.000000     265.000000       4.000000     446.100000
# std        62.661207      68.657427       0.516893      17.241348
#
#                extra        mta_tax     tip_amount   tolls_amount  \
# count  234244.000000  234244.000000  234244.000000  234244.000000
# mean        1.763517       0.488725       3.497108       0.518409
# min        -7.500000      -0.500000      -2.170000     -27.850000
# 25%         0.000000       0.500000       1.000000       0.000000
# 50%         1.000000       0.500000       2.900000       0.000000
# 75%         2.500000       0.500000       4.340000       0.000000
# max        11.250000       4.000000     237.150000     177.000000
# std         1.867576       0.097627       3.818645       2.044371
#
#        improvement_surcharge   total_amount  congestion_surcharge  \
# count          234244.000000  234244.000000         228205.000000
# mean                0.982311      27.522062              2.287340
# min                -1.000000    -252.850000             -2.500000
# 25%                 1.000000      16.000000              2.500000
# 50%                 1.000000      21.000000              2.500000
# 75%                 1.000000      29.400000              2.500000
# max                 1.000000     482.450000              2.500000
# std                 0.182196      21.664501              0.754667
#
#          airport_fee
# count  228205.000000
# mean        0.096010
# min        -1.250000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.250000
# std         0.337354

# %%
missing_rows = x.isna().any(axis = 1)
missing_rows.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
missing_rows.sum()
# Out:
# np.int64(6039)

# %%
ax =x[~missing_rows]
ax.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-03-01 00:00:00   2023-03-01 00:28:03              1.0
# 1         2  2023-03-01 00:00:00   2023-03-01 00:00:00              3.0
# 3         2  2023-03-01 00:00:01   2023-03-01 00:25:17              1.0
# 4         2  2023-03-01 00:00:05   2023-03-01 00:14:11              2.0
# 5         2  2023-03-01 00:00:06   2023-03-01 00:12:05              1.0
#
#   trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0         12.77         1.0                  N           138            87
# 1          6.22         1.0                  N           162            13
# 3         13.93         1.0                  N           132           155
# 4           2.9         1.0                  N           234            13
# 5          2.95         1.0                  N           158           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         51.3    6.0      0.5        5.00          6.55
# 1             2         29.6    0.0      0.5        0.00          0.00
# 3             1         54.1    1.0      0.5       11.32          0.00
# 4             1         16.3    1.0      0.5        3.00          0.00
# 5             1         15.6    1.0      0.5        4.12          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    1.0         74.10                   2.5         1.25
# 1                    1.0         33.60                   2.5         0.00
# 3                    1.0         69.17                   0.0         1.25
# 4                    1.0         24.30                   2.5         0.00
# 5                    1.0         24.72                   2.5         0.00

# %%
len(ax)
# Out:
# 228205

# %%
len(x)
# Out:
# 234244

# %%
234244 - 228205
# Out:
# 6039

# %%
abc = ax["total_amount"] >= 0
abc.value_counts()
# Out:
# total_amount
# True     226322
# False      1883
# Name: count, dtype: int64

# %% [markdown]
# # No Duplicated Data Found...only 6039 missing rows removed. The clean data has 228205 rows....

# %%
abc.head(5)
# Out:
# 0    True
# 1    True
# 3    True
# 4    True
# 5    True
# Name: total_amount, dtype: bool

# %%
plt.figure(figsize=(12, 6))
ax["passenger_count"].hist(color = "darkgreen",)
plt.title("Number of Passenger per Rides",fontsize=16)
plt.xlabel("Number of Passenger", fontsize=16)
plt.ylabel("Number of Rides", fontsize=16)
# Out:
# Text(0, 0.5, 'Number of Rides')

# %%
ax.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-03-01 00:00:00   2023-03-01 00:28:03              1.0
# 1         2  2023-03-01 00:00:00   2023-03-01 00:00:00              3.0
# 3         2  2023-03-01 00:00:01   2023-03-01 00:25:17              1.0
# 4         2  2023-03-01 00:00:05   2023-03-01 00:14:11              2.0
# 5         2  2023-03-01 00:00:06   2023-03-01 00:12:05              1.0
#
#   trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0         12.77         1.0                  N           138            87
# 1          6.22         1.0                  N           162            13
# 3         13.93         1.0                  N           132           155
# 4           2.9         1.0                  N           234            13
# 5          2.95         1.0                  N           158           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         51.3    6.0      0.5        5.00          6.55
# 1             2         29.6    0.0      0.5        0.00          0.00
# 3             1         54.1    1.0      0.5       11.32          0.00
# 4             1         16.3    1.0      0.5        3.00          0.00
# 5             1         15.6    1.0      0.5        4.12          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    1.0         74.10                   2.5         1.25
# 1                    1.0         33.60                   2.5         0.00
# 3                    1.0         69.17                   0.0         1.25
# 4                    1.0         24.30                   2.5         0.00
# 5                    1.0         24.72                   2.5         0.00

# %%
ax[["trip_distance", "tip_amount"]].dtypes
# Out:
# trip_distance     object
# tip_amount       float64
# dtype: object

# %%
ax["trip_distance"] = ax["trip_distance"].str.replace(",","")

ax["trip_distance"] = ax["trip_distance"].astype(float)
# Out:
# /tmp/ipykernel_6799/3775958405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ax["trip_distance"] = ax["trip_distance"].str.replace(",","")
# /tmp/ipykernel_6799/3775958405.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ax["trip_distance"] = ax["trip_distance"].astype(float)

# %%
ax[["trip_distance", "tip_amount"]].dtypes
# Out:
# trip_distance    float64
# tip_amount       float64
# dtype: object

# %%
ax["tpep_pickup_datetime"] = pd.to_datetime(ax["tpep_pickup_datetime"])
# Out:
# /tmp/ipykernel_6799/1733982461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ax["tpep_pickup_datetime"] = pd.to_datetime(ax["tpep_pickup_datetime"])

# %%
def maxx(x):
    if x > 0:
        return 1
    else:
        return 0

# %%
ax["toll_x"] = ax["tolls_amount"].apply(maxx)
# Out:
# /tmp/ipykernel_6799/2136712501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ax["toll_x"] = ax["tolls_amount"].apply(maxx)

# %%
plt.figure(figsize=(12, 6))

tx = ax["toll_x"].value_counts()

tx.plot(kind="bar")

plt.title("Trips With Toll vs No Toll")
plt.xlabel("Has Toll (1 = Yes, 0 = No)")
plt.ylabel("Number of Trips")
# Out:
# Text(0, 0.5, 'Number of Trips')

# %%
ax.head(1)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2           2023-03-01   2023-03-01 00:28:03              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          12.77         1.0                  N           138            87
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         51.3    6.0      0.5         5.0          6.55
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                    1.0          74.1                   2.5         1.25
#
#    toll_x
# 0       1

# %%
def rrr(x):
    if x > 0:
        return 1
    else:
        return 0

# %%
ax["c_x"] =ax["congestion_surcharge"].apply(rrr)
# Out:
# /tmp/ipykernel_6799/1868709301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ax["c_x"] =ax["congestion_surcharge"].apply(rrr)

# %%
plt.figure(figsize=(12, 6))

yellow = ax["c_x"].value_counts()
yellow.plot(kind = "barh")
plt.title("Number of rides that paid congestion_surcharge")
plt.ylabel("1= pair, 0 = no paid")
plt.xlabel("Number of Rides")
# Out:
# Text(0.5, 0, 'Number of Rides')

# %%
plt.figure(figsize=(12, 6))

pymn = ax["payment_type"].value_counts()
pymn.plot(kind = "bar")
plt.title("Type of Paynment Used")
plt.ylabel("Number of Rides")
plt.xlabel("Type of Paynment")
# Out:
# Text(0.5, 0, 'Type of Paynment')

# %%
plt.figure(figsize=(12, 6))


aaa = ax.groupby(ax["tpep_pickup_datetime"].dt.hour)["total_amount"].mean()
aaa.plot(kind="line", color = "black")
plt.title("Average Total Amount by Pickup Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Total Amount ($)")
# Out:
# Text(0, 0.5, 'Average Total Amount ($)')

# %%
ax.head(2)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2           2023-03-01   2023-03-01 00:28:03              1.0
# 1         2           2023-03-01   2023-03-01 00:00:00              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          12.77         1.0                  N           138            87
# 1           6.22         1.0                  N           162            13
#
#    payment_type  ...  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1  ...    6.0      0.5         5.0          6.55
# 1             2  ...    0.0      0.5         0.0          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                    1.0          74.1                   2.5         1.25
# 1                    1.0          33.6                   2.5         0.00
#
#    toll_x  c_x
# 0       1    1
# 1       0    1
#
# [2 rows x 21 columns]

# %%
plt.figure(figsize=(12, 6))


aaa = ax.groupby(ax["tpep_pickup_datetime"].dt.hour)["tip_amount"].median()
aaa.plot(kind="line", color = "forestgreen")
plt.title("Average Tip Amount by Pickup Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Total Tip Amount ($)")
# Out:
# Text(0, 0.5, 'Average Total Tip Amount ($)')

# %%
plt.figure(figsize=(12, 6))


aaa = ax.groupby(ax["tpep_dropoff_datetime"].dt.hour)["total_amount"].median()
aaa.plot(kind="line", color = "forestgreen")
plt.title("Average total Amount by dropoff Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Total Amount ($)")
# Out:
# Text(0, 0.5, 'Average Total Amount ($)')

# %%
ax
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2023-03-01 00:00:00   2023-03-01 00:28:03              1.0
# 1              2  2023-03-01 00:00:00   2023-03-01 00:00:00              3.0
# 3              2  2023-03-01 00:00:01   2023-03-01 00:25:17              1.0
# 4              2  2023-03-01 00:00:05   2023-03-01 00:14:11              2.0
# 5              2  2023-03-01 00:00:06   2023-03-01 00:12:05              1.0
# ...          ...                  ...                   ...              ...
# 234237         2  2023-03-02 23:59:57   2023-03-03 00:10:04              2.0
# 234238         2  2023-03-02 23:59:57   2023-03-03 00:22:30              3.0
# 234239         1  2023-03-02 23:59:59   2023-03-03 00:08:10              1.0
# 234241         1  2023-03-03 00:00:00   2023-03-03 00:24:02              1.0
# 234242         2  2023-03-03 00:00:00   2023-03-03 00:04:39              2.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               12.77         1.0                  N           138
# 1                6.22         1.0                  N           162
# 3               13.93         1.0                  N           132
# 4                2.90         1.0                  N           234
# 5                2.95         1.0                  N           158
# ...               ...         ...                ...           ...
# 234237            NaN         1.0                  N           142
# 234238            NaN         1.0                  N           230
# 234239            NaN         1.0                  N            79
# 234241            NaN         1.0                  N           138
# 234242            NaN         1.0                  N           114
#
#         DOLocationID  payment_type  ...  extra  mta_tax  tip_amount  \
# 0                 87             1  ...   6.00      0.5        5.00
# 1                 13             2  ...   0.00      0.5        0.00
# 3                155             1  ...   1.00      0.5       11.32
# 4                 13             1  ...   1.00      0.5        3.00
# 5                163             1  ...   1.00      0.5        4.12
# ...              ...           ...  ...    ...      ...         ...
# 234237           140             1  ...   1.00      0.5        3.00
# 234238           162             1  ...   1.00      0.5        0.00
# 234239           113             1  ...   3.50      0.5        1.00
# 234241            24             1  ...   7.25      0.5        5.00
# 234242           158             1  ...   1.00      0.5        2.16
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 0               6.55                    1.0         74.10
# 1               0.00                    1.0         33.60
# 3               0.00                    1.0         69.17
# 4               0.00                    1.0         24.30
# 5               0.00                    1.0         24.72
# ...              ...                    ...           ...
# 234237          0.00                    1.0         20.10
# 234238          0.00                    1.0         24.80
# 234239          0.00                    1.0         13.90
# 234241          6.55                    1.0         56.20
# 234242          0.00                    1.0         12.96
#
#         congestion_surcharge  airport_fee  toll_x  c_x
# 0                        2.5         1.25       1    1
# 1                        2.5         0.00       0    1
# 3                        0.0         1.25       0    0
# 4                        2.5         0.00       0    1
# 5                        2.5         0.00       0    1
# ...                      ...          ...     ...  ...
# 234237                   2.5         0.00       0    1
# 234238                   2.5         0.00       0    1
# 234239                   2.5         0.00       0    1
# 234241                   0.0         1.25       1    0
# 234242                   2.5         0.00       0    1
#
# [228205 rows x 21 columns]

# %%
ax.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee', 'toll_x', 'c_x'],
#       dtype='object')

# %%
data2 = ax[['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'tip_amount', 'tolls_amount', 'total_amount']]
display(data2.head())
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2023-03-01 00:00:00   2023-03-01 00:28:03              1.0          12.77
# 1  2023-03-01 00:00:00   2023-03-01 00:00:00              3.0           6.22
# 3  2023-03-01 00:00:01   2023-03-01 00:25:17              1.0          13.93
# 4  2023-03-01 00:00:05   2023-03-01 00:14:11              2.0           2.90
# 5  2023-03-01 00:00:06   2023-03-01 00:12:05              1.0           2.95
#
#    tip_amount  tolls_amount  total_amount
# 0        5.00          6.55         74.10
# 1        0.00          0.00         33.60
# 3       11.32          0.00         69.17
# 4        3.00          0.00         24.30
# 5        4.12          0.00         24.72

# %% [markdown]
# # Step 8

# %%
data2.columns
# Out:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'tip_amount', 'tolls_amount', 'total_amount'],
#       dtype='object')

# %%
data2 = data2[data2['trip_distance'] < 150]
data2 = data2[data2['total_amount'] > 0]

# %%
data2 = data2[data2['trip_distance'] > 0.1]
data2 = data2[(data2['passenger_count'] > 0) & (data2['passenger_count'] <= 6)]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data2 = data2.dropna()

# %%
X = data2[['trip_distance', 'passenger_count']]
y = data2['total_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Model 1 Results:")
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# Model 1 Results:
# MSE: 49.09419121722445
# R2: 0.8952970228057454

# %%
model1 = smf.ols(formula='total_amount ~ trip_distance + passenger_count', data=data2).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           total_amount   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                 6.317e+05
# Date:                Sun, 05 Apr 2026   Prob (F-statistic):               0.00
# Time:                        15:41:11   Log-Likelihood:            -5.1800e+05
# No. Observations:              152849   AIC:                         1.036e+06
# Df Residuals:                  152846   BIC:                         1.036e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          12.1630      0.036    335.226      0.000      12.092      12.234
# trip_distance       4.6818      0.004   1122.837      0.000       4.674       4.690
# passenger_count     0.0522      0.022      2.393      0.017       0.009       0.095
# ==============================================================================
# Omnibus:                   156704.512   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        114197284.443
# Skew:                           4.242   Prob(JB):                         0.00
# Kurtosis:                     136.638   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Step 8..Model 2

# %%
X = data2[['trip_distance', 'passenger_count', 'tip_amount', 'tolls_amount']]
y = data2['total_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Step 8, Model 2 Results,L.G.:")
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# Step 8, Model 2 Results,L.G.:
# MSE: 30.167223213410526
# R2: 0.9382076900982725

# %%
model2 = smf.ols(formula='total_amount ~ trip_distance + passenger_count + tip_amount + tolls_amount', data=data2).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           total_amount   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                 6.576e+05
# Date:                Sun, 05 Apr 2026   Prob (F-statistic):               0.00
# Time:                        15:41:12   Log-Likelihood:            -4.6637e+05
# No. Observations:              152849   AIC:                         9.328e+05
# Df Residuals:                  152844   BIC:                         9.328e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          10.3868      0.028    376.648      0.000      10.333      10.441
# trip_distance       3.5449      0.004    811.707      0.000       3.536       3.553
# passenger_count     0.0980      0.016      6.302      0.000       0.068       0.129
# tip_amount          1.3636      0.004    318.861      0.000       1.355       1.372
# tolls_amount        1.2929      0.008    157.629      0.000       1.277       1.309
# ==============================================================================
# Omnibus:                   244575.076   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1303345501.398
# Skew:                           9.616   Prob(JB):                         0.00
# Kurtosis:                     454.972   Cond. No.                         17.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(6, 5))

sns.scatterplot(x=y_test, y=y_pred, color = "darkgreen")
plt.xlabel("Actual Total Amount")
plt.ylabel("Predicted Total Amount")
plt.title("Actual vs Predicted Taxi Fare")

plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)])

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(x="trip_distance", y="total_amount", data=data2, color = "red")

plt.xlabel("Trip Distance")
plt.ylabel("Total Amount")
plt.title("Trip Distance vs Total Fare")
# Out:
# Text(0.5, 1.0, 'Trip Distance vs Total Fare')

# %% [markdown]
# #Step 9

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
X = data2[['trip_distance', 'passenger_count', 'tip_amount', 'tolls_amount']]
y = data2['total_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model_knn = KNeighborsRegressor(n_neighbors=5)
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn = model_knn.predict(X_test)

print("KNN Model Results:")
print("MSE:", mean_squared_error(y_test, y_pred_knn))
print("R2:", r2_score(y_test, y_pred_knn))
# Out:
# KNN Model Results:
# MSE: 18.973870015963364
# R2: 0.9597503182891889

# %%
plt.figure(figsize=(12, 6))

plt.scatter(y_test, y_pred, label="Linear Regression", color = "red", alpha=0.5)
plt.scatter(y_test, y_pred_knn, label="KNN", color = "blue", alpha=0.5)
plt.legend()

plt.xlabel("Actual Total Amount")
plt.ylabel("Predicted Total Amount")
plt.title("Actual vs Predicted Taxi Fare")

plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)],color='black')

# %%
plt.figure(figsize=(12, 6))

sns.scatterplot(x = y_test, y = y_pred_knn, color = "darkgreen", alpha=0.9)

plt.xlabel("Actual Total Amount")
plt.ylabel("Predicted Total Amount")
plt.title("Actual vs Predicted Taxi Fare, KNN")

plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)],color='black')
